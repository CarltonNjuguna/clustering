# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_stata("HCMST 2017 fresh sample for public sharing draft v1.1.dta")

# %%
for i,name in enumerate(df.columns):
    if df[name].dtypes == 'category':
        df[name] = df[name].astype('str')

# %%
df['S1']
# Out:
# 0       No, I am not Married
# 1          Yes, I am Married
# 2          Yes, I am Married
# 3       No, I am not Married
# 4          Yes, I am Married
#                 ...
# 3505       Yes, I am Married
# 3506    No, I am not Married
# 3507       Yes, I am Married
# 3508    No, I am not Married
# 3509    No, I am not Married
# Name: S1, Length: 3510, dtype: object

# %%
df1 = df[df['S1'] == 'Yes, I am Married']
dft = df[df['S1'] == 'No, I am not Married' ]
df2 = df[df['S2'] == 'No, I am single, with no boyfriend, no girlfriend and no romantic or sexual partner']
df3 = dft[dft['S2'] != 'No, I am single, with no boyfriend, no girlfriend and no romantic or sexual partner']
#grouped = df.groupby(df['Name'])

# %%
df1= pd.read_csv('csv1.csv')
df2= pd.read_csv('csv2.csv')
df3= pd.read_csv('csv3.csv')

# %%
tab = [df1,df2,df3]

# %%
tab[0]['speed_flag'].unique()
# Out:
# array(['Completed survey in over 2 minutes',
#        'Completed survey in under 2 minutes'], dtype=object)

# %%
for i in range(0,3):
    print(i)
    tab[i] = tab[i].drop(tab[i][tab[i]['speed_flag'] == 'Completed survey in under 2 minutes'].index)
    del tab[i]['speed_flag']
# Out:
# 0
# 1
# 2

# %%
for i in range(0,3):
    for j in range(1,16):
        del tab[i][f'race{j}']

# %%
tab[0].head(15)
# Out:
#     Unnamed: 0  CaseID  CASEID_NEW      qflag   weight1  weight1_freqwt  \
# 0            1       3     2019003  Qualified    0.9078         71115.0
# 1            2       5     2145527  Qualified    0.7205         56442.0
# 2            4       7     2623465  Qualified    0.8686         68044.0
# 3            5       9     2917189  Qualified    0.8815         69054.0
# 4            6      10     2919423  Qualified    0.8381         65655.0
# 5            7      11     2936569  Qualified    0.7752         60727.0
# 6           10      14     2089701  Qualified    0.8716         68279.0
# 7           14      18     2710813  Qualified    0.9109         71358.0
# 8           15      20     2578951  Qualified       NaN             NaN
# 9           17      22     2690979  Qualified    0.9338         73152.0
# 10          18      23     1861177  Qualified    0.7498         58737.0
# 11          19      24      782115  Qualified  911.0000         71365.0
# ...
